# %%
#import splitfolders
#splitfolders.ratio('Mushrooms', output="data", seed=1706, ratio=(.8, .0, .2)) # 这里Mushrooms是原始数据文件夹，data是切分后的数据文件夹

# %%
import mindspore.dataset as ds # 数据集载入
import mindspore.nn as nn # 各类网络层都在nn里面
from mindspore.train.callback import ModelCheckpoint, CheckpointConfig, LossMonitor, TimeMonitor # 回调函数
from mindspore.train import Model # 承载网络结构
from mindspore import load_checkpoint # 读取最佳参数
from mindspore import context # 设置mindspore运行的环境

from easydict import EasyDict as ed # 超参数保存
import numpy as np # numpy
import matplotlib.pyplot as plt # 可视化

# 文件处理相关
import os

# 华为云文件传输相关
import moxing
# Out:
# INFO:root:Using MoXing-v2.0.0.rc2.4b57a67b-4b57a67b
# INFO:root:Using OBS-Python-SDK-3.20.9.1

# %%
device_target = context.get_context('device_target') # 获取运行装置（CPU，GPU，Ascend）
dataset_sink_mode = True if device_target in ['Ascend','GPU'] else False # 是否将数据通过pipeline下发到装置上
context.set_context(mode = context.GRAPH_MODE, device_target = device_target) # 设置运行环境，静态图context.GRAPH_MODE指向静态图模型，即在运行之前会把全部图建立编译完毕

print(f'device_target: {device_target}')
print(f'dataset_sink_mode: {dataset_sink_mode}')
# Out:
# device_target: Ascend
# dataset_sink_mode: True

# %%
# 数据路径
train_path = os.path.join('data', 'train')
test_path = os.path.join('data', 'test')

# 超参数
config = ed({
    # 训练参数
    'batch_size': 32,
    'epochs': 150,
    
    #网络参数
    'class_num': 2,

    # 动态学习率调节
    'warmup_epochs': 5,
    'lr_init': 0.01,
    'lr_max': 0.1,

    # 优化器参数
    'momentum': 0.9,
    'weight_decay': 4e-5})

# %%
# 创建图像标签列表
category_dict = {0:'Agaricus',1:'Amanita',2:'Boletus',3:'Cortinarius',4:'Entoloma',
                 5:'Hygrocybe',6:'Lactarius',7:'Russula',8:'Suillus'}

# 载入展示用数据
demo_ds = ds.ImageFolderDataset(test_path, decode=True)

# 设置图像大小
plt.figure(figsize=(6, 6))

# 打印9张子图
i = 1
for dic in demo_ds.create_dict_iterator():
    plt.subplot(3,3,i)
    plt.imshow(dic['image'].asnumpy()) # asnumpy：将 MindSpore tensor 转换成 numpy
    plt.axis('off')
    plt.title(category_dict[dic['label'].asnumpy().item()])
    i +=1
    if i > 2 :
        break

plt.show()

# %%
train_ds = ds.ImageFolderDataset(train_path, decode=True)
#计算数据集平均数和标准差，数据标准化时使用
tmp = np.asarray( [np.mean(x['image'], axis=(0, 1)) for x in train_ds.create_dict_iterator(output_numpy=True)] )
RGB_mean = tuple(np.mean(tmp, axis=(0)))
RGB_std = tuple(np.std(tmp, axis=(0)))

print(RGB_mean)
print(RGB_std)
# Out:
# (118.01461003978233, 109.76053261923568, 95.03887508735055)
# (34.049584856430016, 28.22710970450829, 32.25595446557889)

# %%
from preprocess import create_dataset

# %%
# 这里将网络分为backbone和head，backbone是ResNet包含残差块的部分，head是最后的全连接层。
from network import resnet50_backbone, resnet50_head

# 最终网络由backbone和head组成。
class ResNet50(nn.Cell):
    """
    ResNet architecture.

    Args:
        backbone (Cell): ResNet50 backbone网络
        head (Cell): ResNet50 head网络
    Returns:
        Tensor, 输出张量

    Examples:
        >>> ResNet50(resnet_backbone,
        >>>          resnet_head)
    """

    def __init__(self, backbone, head):
        super(ResNet50, self).__init__()

        self.backbone = backbone
        self.head = head

    def construct(self, x):
        x = self.backbone(x)
        x = self.head(x)
        return x

# %%
# 训练集
train_data = create_dataset(data_path=train_path, 
                            mean=RGB_mean, 
                            std=RGB_std, 
                            batch_size=config.batch_size, 
                            usage='train',
                            repeat_num=1)

# 测试集
test_data = create_dataset(data_path=test_path, 
                            mean=RGB_mean, 
                            std=RGB_std, 
                            batch_size=config.batch_size, 
                            usage='test',
                            repeat_num=1)

# %%
from lr_scheduler import get_lr

# 训练step总数
train_step_size = train_data.get_dataset_size()

# 学习率数组
lr = get_lr(total_epochs=config.epochs, 
            steps_per_epoch=train_step_size,
            lr_init=config.lr_init,
            lr_max=config.lr_max,
            warmup_epochs=config.warmup_epochs)

# %%
# 网络
backbone_net = resnet50_backbone() # backbone网络，保存后能提供后续迁移学习使用
head_net = resnet50_head(config.class_num) # head网络，resnet50最后的全连接层
net = ResNet50(backbone_net, head_net)

# 损失函数
net_loss = nn.SoftmaxCrossEntropyWithLogits(sparse=True, reduction='mean')

# 优化器
opt = nn.Momentum(net.trainable_params(), lr, momentum=config.momentum, weight_decay=config.weight_decay)

# 模型
model = Model(net, loss_fn = net_loss,
              optimizer = opt, metrics = {'accuracy','loss'})

# %%
from network import MobileNetV2Backbone
backbone_net = MobileNetV2Backbone()
load_checkpoint('best_param_backbone.ckpt', backbone_net)
# Out:
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.328.14 [mindspore/train/serialization.py:568] 260 parameters in the net are not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.344.83 [mindspore/train/serialization.py:570] features.0.features.0.weight is not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.352.52 [mindspore/train/serialization.py:570] features.0.features.1.moving_mean is not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.360.25 [mindspore/train/serialization.py:570] features.0.features.1.moving_variance is not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.367.50 [mindspore/train/serialization.py:570] features.0.features.1.gamma is not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.374.62 [mindspore/train/serialization.py:570] features.0.features.1.beta is not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.381.79 [mindspore/train/serialization.py:570] features.1.conv.0.features.0.weight is not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.389.04 [mindspore/train/serialization.py:570] features.1.conv.0.features.1.moving_mean is not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.396.14 [mindspore/train/serialization.py:570] features.1.conv.0.features.1.moving_variance is not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.403.21 [mindspore/train/serialization.py:570] features.1.conv.0.features.1.gamma is not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.410.42 [mindspore/train/serialization.py:570] features.1.conv.0.features.1.beta is not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.417.45 [mindspore/train/serialization.py:570] features.1.conv.1.weight is not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.424.56 [mindspore/train/serialization.py:570] features.1.conv.2.moving_mean is not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.431.55 [mindspore/train/serialization.py:570] features.1.conv.2.moving_variance is not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.438.46 [mindspore/train/serialization.py:570] features.1.conv.2.gamma is not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.445.71 [mindspore/train/serialization.py:570] features.1.conv.2.beta is not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.452.69 [mindspore/train/serialization.py:570] features.2.conv.0.features.0.weight is not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.459.69 [mindspore/train/serialization.py:570] features.2.conv.0.features.1.moving_mean is not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.466.64 [mindspore/train/serialization.py:570] features.2.conv.0.features.1.moving_variance is not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.473.72 [mindspore/train/serialization.py:570] features.2.conv.0.features.1.gamma is not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.480.86 [mindspore/train/serialization.py:570] features.2.conv.0.features.1.beta is not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.487.87 [mindspore/train/serialization.py:570] features.2.conv.1.features.0.weight is not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.494.82 [mindspore/train/serialization.py:570] features.2.conv.1.features.1.moving_mean is not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.501.77 [mindspore/train/serialization.py:570] features.2.conv.1.features.1.moving_variance is not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.508.67 [mindspore/train/serialization.py:570] features.2.conv.1.features.1.gamma is not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.515.63 [mindspore/train/serialization.py:570] features.2.conv.1.features.1.beta is not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.522.82 [mindspore/train/serialization.py:570] features.2.conv.2.weight is not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50
not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.215.832 [mindspore/train/serialization.py:570] features.18.features.1.gamma is not loaded.
# [WARNING] ME(9165:281473332725200,MainProcess):2022-05-15-16:00:50.216.540 [mindspore/train/serialization.py:570] features.18.features.1.beta is not loaded.
# {'backbone.conv1.weight': Parameter (name=backbone.conv1.weight, shape=(64, 3, 7, 7), dtype=Float32, requires_grad=True),
#  'backbone.bn1.moving_mean': Parameter (name=backbone.bn1.moving_mean, shape=(64,), dtype=Float32, requires_grad=True),
#  'backbone.bn1.moving_variance': Parameter (name=backbone.bn1.moving_variance, shape=(64,), dtype=Float32, requires_grad=True),
#  'backbone.bn1.gamma': Parameter (name=backbone.bn1.gamma, shape=(64,), dtype=Float32, requires_grad=True),
#  'backbone.bn1.beta': Parameter (name=backbone.bn1.beta, shape=(64,), dtype=Float32, requires_grad=True),
#  'backbone.layer1.0.conv1.weight': Parameter (name=backbone.layer1.0.conv1.weight, shape=(64, 64, 1, 1), dtype=Float32, requires_grad=True),
#  'backbone.layer1.0.bn1.moving_mean': Parameter (name=backbone.layer1.0.bn1.moving_mean, shape=(64,), dtype=Float32, requires_grad=True),
#  'backbone.layer1.0.bn1.moving_variance': Parameter (name=backbone.layer1.0.bn1.moving_variance, shape=(64,), dtype=Float32, requires_grad=True),
#  'backbone.layer1.0.bn1.gamma': Parameter (name=backbone.layer1.0.bn1.gamma, shape=(64,), dtype=Float32, requires_grad=True),
#  'backbone.layer1.0.bn1.beta': Parameter (name=backbone.layer1.0.bn1.beta, shape=(64,), dtype=Float32, requires_grad=True),
#  'backbone.layer1.0.conv2.weight': Parameter (name=backbone.layer1.0.conv2.weight, shape=(64, 64, 3, 3), dtype=Float32, requires_grad=True),
#  'backbone.layer1.0.bn2.moving_mean': Parameter (name=backbone.layer1.0.bn2.moving_mean, shape=(64,), dtype=Float32, requires_grad=True),
#  'backbone.layer1.0.bn2.moving_variance': Parameter (name=backbone.layer1.0.bn2.moving_variance, shape=(64,), dtype=Float32, requires_grad=True),
#  'backbone.layer1.0.bn2.gamma': Parameter (name=backbone.layer1.0.bn2.gamma, shape=(64,), dtype=Float32, requires_grad=True),
#  'backbone.layer1.0.bn2.beta': Parameter (name=backbone.layer1.0.bn2.beta, shape=(64,), dtype=Float32, requires_grad=True),
#  'backbone.layer1.0.conv3.weight': Parameter (name=backbone.layer1.0.conv3.weight, shape=(256, 64, 1, 1), dtype=Float32, requires_grad=True),
#  'backbone.layer1.0.bn3.moving_mean': Parameter (name=backbone.layer1.0.bn3.moving_mean, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer1.0.bn3.moving_variance': Parameter (name=backbone.layer1.0.bn3.moving_variance, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer1.0.bn3.gamma': Parameter (name=backbone.layer1.0.bn3.gamma, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer1.0.bn3.beta': Parameter (name=backbone.layer1.0.bn3.beta, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer1.0.down_sample_layer.0.weight': Parameter (name=backbone.layer1.0.down_sample_layer.0.weight, shape=(256, 64, 1, 1), dtype=Float32, requires_grad=True),
#  'backbone.layer1.0.down_sample_layer.1.moving_mean': Parameter (name=backbone.layer1.0.down_sample_layer.1.moving_mean, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer1.0.down_sample_layer.1.moving_variance': Parameter (name=backbone.layer1.0.down_sample_layer.1.moving_variance, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer1.0.down_sample_layer.1.gamma': Parameter (name=backbone.layer1.0.down_sample_layer.1.gamma, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer1.0.down_sample_layer.1.beta': Parameter (name=backbone.layer1.0.down_sample_layer.1.beta, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer1.1.conv1.weight': Parameter (name=backbone.layer1.1.conv1.weight, shape=(64, 256, 1, 1), dtype=Float32, requires_grad=True),
#  'backbone.layer1.1.bn1.moving_mean': Parameter (name=backbone.layer1.1.bn1.moving_mean, shape=(64,), dtype=Float32, requires_grad=True),
#  'backbone.layer1.1.bn1.moving_variance': Parameter (name=backbone.layer1.1.bn1.moving_variance, shape=(64,), dtype=Float32, requires_grad=True),
#  'backbone.layer1.1.bn1.gamma': Parameter (name=backbone.layer1.1.bn1.gamma, shape=(64,), dtype=Float32, requires_grad=True),
#  'backbone.layer1.1.bn1.beta': Parameter (name=backbone.layer1.1.bn1.beta, shape=(64,), dtype=Float32, requires_grad=True),
#  'backbone.layer1.1.conv2.weight': Parameter (name=backbone.layer1.1.conv2.weight, shape=(64, 64, 3, 3), dtype=Float32, requires_grad=True),
#  'backbone.layer1.1.bn2.moving_mean': Parameter (name=backbone.layer1.1.bn2.moving_mean, shape=(64,), dtype=Float32, requires_grad=True),
#  'backbone.layer1.1.bn2.moving_variance': Parameter (name=backbone.layer1.1.bn2.moving_variance, shape=(64,), dtype=Float32, requires_grad=True),
#  'backbone.layer1.1.bn2.gamma': Parameter (name=backbone.layer1.1.bn2.gamma, shape=(64,), dtype=Float32, requires_grad=True),
#  'backbone.layer1.1.bn2.beta': Parameter (name=backbone.layer1.1.bn2.beta, shape=(64,), dtype=Float32, requires_grad=True),
#  'backbone.layer1.1.conv3.weight': Parameter (name=backbone.layer1.1.conv3.weight, shape=(256, 64, 1, 1), dtype=Float32, requires_grad=True),
#  'backbone.layer1.1.bn3.moving_mean': Parameter (name=backbone.layer1.1.bn3.moving_mean, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer1.1.bn3.moving_variance': Parameter (name=backbone.layer1.1.bn3.moving_variance, shape=(256,), dtype=Float32, requires_grad=True),
# ...
#  'backbone.layer3.1.bn2.beta': Parameter (name=backbone.layer3.1.bn2.beta, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.1.conv3.weight': Parameter (name=backbone.layer3.1.conv3.weight, shape=(1024, 256, 1, 1), dtype=Float32, requires_grad=True),
#  'backbone.layer3.1.bn3.moving_mean': Parameter (name=backbone.layer3.1.bn3.moving_mean, shape=(1024,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.1.bn3.moving_variance': Parameter (name=backbone.layer3.1.bn3.moving_variance, shape=(1024,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.1.bn3.gamma': Parameter (name=backbone.layer3.1.bn3.gamma, shape=(1024,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.1.bn3.beta': Parameter (name=backbone.layer3.1.bn3.beta, shape=(1024,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.2.conv1.weight': Parameter (name=backbone.layer3.2.conv1.weight, shape=(256, 1024, 1, 1), dtype=Float32, requires_grad=True),
#  'backbone.layer3.2.bn1.moving_mean': Parameter (name=backbone.layer3.2.bn1.moving_mean, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.2.bn1.moving_variance': Parameter (name=backbone.layer3.2.bn1.moving_variance, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.2.bn1.gamma': Parameter (name=backbone.layer3.2.bn1.gamma, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.2.bn1.beta': Parameter (name=backbone.layer3.2.bn1.beta, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.2.conv2.weight': Parameter (name=backbone.layer3.2.conv2.weight, shape=(256, 256, 3, 3), dtype=Float32, requires_grad=True),
#  'backbone.layer3.2.bn2.moving_mean': Parameter (name=backbone.layer3.2.bn2.moving_mean, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.2.bn2.moving_variance': Parameter (name=backbone.layer3.2.bn2.moving_variance, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.2.bn2.gamma': Parameter (name=backbone.layer3.2.bn2.gamma, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.2.bn2.beta': Parameter (name=backbone.layer3.2.bn2.beta, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.2.conv3.weight': Parameter (name=backbone.layer3.2.conv3.weight, shape=(1024, 256, 1, 1), dtype=Float32, requires_grad=True),
#  'backbone.layer3.2.bn3.moving_mean': Parameter (name=backbone.layer3.2.bn3.moving_mean, shape=(1024,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.2.bn3.moving_variance': Parameter (name=backbone.layer3.2.bn3.moving_variance, shape=(1024,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.2.bn3.gamma': Parameter (name=backbone.layer3.2.bn3.gamma, shape=(1024,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.2.bn3.beta': Parameter (name=backbone.layer3.2.bn3.beta, shape=(1024,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.3.conv1.weight': Parameter (name=backbone.layer3.3.conv1.weight, shape=(256, 1024, 1, 1), dtype=Float32, requires_grad=True),
#  'backbone.layer3.3.bn1.moving_mean': Parameter (name=backbone.layer3.3.bn1.moving_mean, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.3.bn1.moving_variance': Parameter (name=backbone.layer3.3.bn1.moving_variance, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.3.bn1.gamma': Parameter (name=backbone.layer3.3.bn1.gamma, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.3.bn1.beta': Parameter (name=backbone.layer3.3.bn1.beta, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.3.conv2.weight': Parameter (name=backbone.layer3.3.conv2.weight, shape=(256, 256, 3, 3), dtype=Float32, requires_grad=True),
#  'backbone.layer3.3.bn2.moving_mean': Parameter (name=backbone.layer3.3.bn2.moving_mean, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.3.bn2.moving_variance': Parameter (name=backbone.layer3.3.bn2.moving_variance, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.3.bn2.gamma': Parameter (name=backbone.layer3.3.bn2.gamma, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.3.bn2.beta': Parameter (name=backbone.layer3.3.bn2.beta, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.3.conv3.weight': Parameter (name=backbone.layer3.3.conv3.weight, shape=(1024, 256, 1, 1), dtype=Float32, requires_grad=True),
#  'backbone.layer3.3.bn3.moving_mean': Parameter (name=backbone.layer3.3.bn3.moving_mean, shape=(1024,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.3.bn3.moving_variance': Parameter (name=backbone.layer3.3.bn3.moving_variance, shape=(1024,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.3.bn3.gamma': Parameter (name=backbone.layer3.3.bn3.gamma, shape=(1024,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.3.bn3.beta': Parameter (name=backbone.layer3.3.bn3.beta, shape=(1024,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.4.conv1.weight': Parameter (name=backbone.layer3.4.conv1.weight, shape=(256, 1024, 1, 1), dtype=Float32, requires_grad=True),
#  'backbone.layer3.4.bn1.moving_mean': Parameter (name=backbone.layer3.4.bn1.moving_mean, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.4.bn1.moving_variance': Parameter (name=backbone.layer3.4.bn1.moving_variance, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.4.bn1.gamma': Parameter (name=backbone.layer3.4.bn1.gamma, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.4.bn1.beta': Parameter (name=backbone.layer3.4.bn1.beta, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.4.conv2.weight': Parameter (name=backbone.layer3.4.conv2.weight, shape=(256, 256, 3, 3), dtype=Float32, requires_grad=True),
#  'backbone.layer3.4.bn2.moving_mean': Parameter (name=backbone.layer3.4.bn2.moving_mean, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.4.bn2.moving_variance': Parameter (name=backbone.layer3.4.bn2.moving_variance, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.4.bn2.gamma': Parameter (name=backbone.layer3.4.bn2.gamma, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.4.bn2.beta': Parameter (name=backbone.layer3.4.bn2.beta, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.4.conv3.weight': Parameter (name=backbone.layer3.4.conv3.weight, shape=(1024, 256, 1, 1), dtype=Float32, requires_grad=True),
#  'backbone.layer3.4.bn3.moving_mean': Parameter (name=backbone.layer3.4.bn3.moving_mean, shape=(1024,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.4.bn3.moving_variance': Parameter (name=backbone.layer3.4.bn3.moving_variance, shape=(1024,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.4.bn3.gamma': Parameter (name=backbone.layer3.4.bn3.gamma, shape=(1024,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.4.bn3.beta': Parameter (name=backbone.layer3.4.bn3.beta, shape=(1024,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.5.conv1.weight': Parameter (name=backbone.layer3.5.conv1.weight, shape=(256, 1024, 1, 1), dtype=Float32, requires_grad=True),
#  'backbone.layer3.5.bn1.moving_mean': Parameter (name=backbone.layer3.5.bn1.moving_mean, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.5.bn1.moving_variance': Parameter (name=backbone.layer3.5.bn1.moving_variance, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.5.bn1.gamma': Parameter (name=backbone.layer3.5.bn1.gamma, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.5.bn1.beta': Parameter (name=backbone.layer3.5.bn1.beta, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.5.conv2.weight': Parameter (name=backbone.layer3.5.conv2.weight, shape=(256, 256, 3, 3), dtype=Float32, requires_grad=True),
#  'backbone.layer3.5.bn2.moving_mean': Parameter (name=backbone.layer3.5.bn2.moving_mean, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.5.bn2.moving_variance': Parameter (name=backbone.layer3.5.bn2.moving_variance, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.5.bn2.gamma': Parameter (name=backbone.layer3.5.bn2.gamma, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.5.bn2.beta': Parameter (name=backbone.layer3.5.bn2.beta, shape=(256,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.5.conv3.weight': Parameter (name=backbone.layer3.5.conv3.weight, shape=(1024, 256, 1, 1), dtype=Float32, requires_grad=True),
#  'backbone.layer3.5.bn3.moving_mean': Parameter (name=backbone.layer3.5.bn3.moving_mean, shape=(1024,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.5.bn3.moving_variance': Parameter (name=backbone.layer3.5.bn3.moving_variance, shape=(1024,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.5.bn3.gamma': Parameter (name=backbone.layer3.5.bn3.gamma, shape=(1024,), dtype=Float32, requires_grad=True),
#  'backbone.layer3.5.bn3.beta': Parameter (name=backbone.layer3.5.bn3.beta, shape=(1024,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.0.conv1.weight': Parameter (name=backbone.layer4.0.conv1.weight, shape=(512, 1024, 1, 1), dtype=Float32, requires_grad=True),
#  'backbone.layer4.0.bn1.moving_mean': Parameter (name=backbone.layer4.0.bn1.moving_mean, shape=(512,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.0.bn1.moving_variance': Parameter (name=backbone.layer4.0.bn1.moving_variance, shape=(512,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.0.bn1.gamma': Parameter (name=backbone.layer4.0.bn1.gamma, shape=(512,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.0.bn1.beta': Parameter (name=backbone.layer4.0.bn1.beta, shape=(512,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.0.conv2.weight': Parameter (name=backbone.layer4.0.conv2.weight, shape=(512, 512, 3, 3), dtype=Float32, requires_grad=True),
#  'backbone.layer4.0.bn2.moving_mean': Parameter (name=backbone.layer4.0.bn2.moving_mean, shape=(512,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.0.bn2.moving_variance': Parameter (name=backbone.layer4.0.bn2.moving_variance, shape=(512,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.0.bn2.gamma': Parameter (name=backbone.layer4.0.bn2.gamma, shape=(512,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.0.bn2.beta': Parameter (name=backbone.layer4.0.bn2.beta, shape=(512,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.0.conv3.weight': Parameter (name=backbone.layer4.0.conv3.weight, shape=(2048, 512, 1, 1), dtype=Float32, requires_grad=True),
#  'backbone.layer4.0.bn3.moving_mean': Parameter (name=backbone.layer4.0.bn3.moving_mean, shape=(2048,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.0.bn3.moving_variance': Parameter (name=backbone.layer4.0.bn3.moving_variance, shape=(2048,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.0.bn3.gamma': Parameter (name=backbone.layer4.0.bn3.gamma, shape=(2048,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.0.bn3.beta': Parameter (name=backbone.layer4.0.bn3.beta, shape=(2048,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.0.down_sample_layer.0.weight': Parameter (name=backbone.layer4.0.down_sample_layer.0.weight, shape=(2048, 1024, 1, 1), dtype=Float32, requires_grad=True),
#  'backbone.layer4.0.down_sample_layer.1.moving_mean': Parameter (name=backbone.layer4.0.down_sample_layer.1.moving_mean, shape=(2048,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.0.down_sample_layer.1.moving_variance': Parameter (name=backbone.layer4.0.down_sample_layer.1.moving_variance, shape=(2048,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.0.down_sample_layer.1.gamma': Parameter (name=backbone.layer4.0.down_sample_layer.1.gamma, shape=(2048,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.0.down_sample_layer.1.beta': Parameter (name=backbone.layer4.0.down_sample_layer.1.beta, shape=(2048,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.1.conv1.weight': Parameter (name=backbone.layer4.1.conv1.weight, shape=(512, 2048, 1, 1), dtype=Float32, requires_grad=True),
#  'backbone.layer4.1.bn1.moving_mean': Parameter (name=backbone.layer4.1.bn1.moving_mean, shape=(512,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.1.bn1.moving_variance': Parameter (name=backbone.layer4.1.bn1.moving_variance, shape=(512,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.1.bn1.gamma': Parameter (name=backbone.layer4.1.bn1.gamma, shape=(512,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.1.bn1.beta': Parameter (name=backbone.layer4.1.bn1.beta, shape=(512,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.1.conv2.weight': Parameter (name=backbone.layer4.1.conv2.weight, shape=(512, 512, 3, 3), dtype=Float32, requires_grad=True),
#  'backbone.layer4.1.bn2.moving_mean': Parameter (name=backbone.layer4.1.bn2.moving_mean, shape=(512,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.1.bn2.moving_variance': Parameter (name=backbone.layer4.1.bn2.moving_variance, shape=(512,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.1.bn2.gamma': Parameter (name=backbone.layer4.1.bn2.gamma, shape=(512,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.1.bn2.beta': Parameter (name=backbone.layer4.1.bn2.beta, shape=(512,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.1.conv3.weight': Parameter (name=backbone.layer4.1.conv3.weight, shape=(2048, 512, 1, 1), dtype=Float32, requires_grad=True),
#  'backbone.layer4.1.bn3.moving_mean': Parameter (name=backbone.layer4.1.bn3.moving_mean, shape=(2048,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.1.bn3.moving_variance': Parameter (name=backbone.layer4.1.bn3.moving_variance, shape=(2048,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.1.bn3.gamma': Parameter (name=backbone.layer4.1.bn3.gamma, shape=(2048,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.1.bn3.beta': Parameter (name=backbone.layer4.1.bn3.beta, shape=(2048,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.2.conv1.weight': Parameter (name=backbone.layer4.2.conv1.weight, shape=(512, 2048, 1, 1), dtype=Float32, requires_grad=True),
#  'backbone.layer4.2.bn1.moving_mean': Parameter (name=backbone.layer4.2.bn1.moving_mean, shape=(512,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.2.bn1.moving_variance': Parameter (name=backbone.layer4.2.bn1.moving_variance, shape=(512,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.2.bn1.gamma': Parameter (name=backbone.layer4.2.bn1.gamma, shape=(512,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.2.bn1.beta': Parameter (name=backbone.layer4.2.bn1.beta, shape=(512,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.2.conv2.weight': Parameter (name=backbone.layer4.2.conv2.weight, shape=(512, 512, 3, 3), dtype=Float32, requires_grad=True),
#  'backbone.layer4.2.bn2.moving_mean': Parameter (name=backbone.layer4.2.bn2.moving_mean, shape=(512,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.2.bn2.moving_variance': Parameter (name=backbone.layer4.2.bn2.moving_variance, shape=(512,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.2.bn2.gamma': Parameter (name=backbone.layer4.2.bn2.gamma, shape=(512,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.2.bn2.beta': Parameter (name=backbone.layer4.2.bn2.beta, shape=(512,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.2.conv3.weight': Parameter (name=backbone.layer4.2.conv3.weight, shape=(2048, 512, 1, 1), dtype=Float32, requires_grad=True),
#  'backbone.layer4.2.bn3.moving_mean': Parameter (name=backbone.layer4.2.bn3.moving_mean, shape=(2048,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.2.bn3.moving_variance': Parameter (name=backbone.layer4.2.bn3.moving_variance, shape=(2048,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.2.bn3.gamma': Parameter (name=backbone.layer4.2.bn3.gamma, shape=(2048,), dtype=Float32, requires_grad=True),
#  'backbone.layer4.2.bn3.beta': Parameter (name=backbone.layer4.2.bn3.beta, shape=(2048,), dtype=Float32, requires_grad=True)}

# %%
from callbacks import TrainHistroy,EvalHistory
time_cb = TimeMonitor(data_size=train_step_size) # 监控每次迭代的时间
loss_cb = LossMonitor() # 监控loss值
hist = {'loss':[], 'loss_eval':[], 'acc_eval':[]} # 训练过程记录

# 记录每次迭代的模型准确率
train_hist_cb = TrainHistroy(hist['loss'])

# 测试并记录模型在验证集的loss和accuracy，并保存最优网络参数
eval_hist_cb = EvalHistory(model = model,
                           backbone = backbone_net,
                           loss_history = hist['loss_eval'], 
                           acc_history = hist['acc_eval'], 
                           eval_data = test_data)

cb = [time_cb, loss_cb, train_hist_cb, eval_hist_cb]

# %%
model.train(config.epochs, train_data, callbacks=cb)
# Out:
# epoch: 1 step: 26, loss is 1.4128696
# acc_eval:  0.9523809523809523
# epoch: 142 step: 26, loss is 0.34074718
# epoch time: 753.622 ms, per step time: 28.985 ms
# acc_eval:  0.9206349206349206
# epoch: 143 step: 26, loss is 0.15195037
# epoch time: 753.747 ms, per step time: 28.990 ms
# acc_eval:  0.9206349206349206
# epoch: 144 step: 26, loss is 0.31253007
# epoch time: 753.182 ms, per step time: 28.969 ms
# acc_eval:  0.9365079365079365
# epoch: 145 step: 26, loss is 0.06750338
# epoch time: 753.131 ms, per step time: 28.967 ms
# acc_eval:  0.9206349206349206
# epoch: 146 step: 26, loss is 0.16391513
# epoch time: 752.788 ms, per step time: 28.953 ms
# acc_eval:  0.9682539682539683
# epoch: 147 step: 26, loss is 0.22333452
# epoch time: 752.930 ms, per step time: 28.959 ms
# acc_eval:  0.9603174603174603
# epoch: 148 step: 26, loss is 0.18141076
# epoch time: 755.831 ms, per step time: 29.070 ms
# acc_eval:  0.9523809523809523
# epoch: 149 step: 26, loss is 0.07528435
# epoch time: 751.682 ms, per step time: 28.911 ms
# acc_eval:  0.9444444444444444
# epoch: 150 step: 26, loss is 0.18182173
# epoch time: 751.732 ms, per step time: 28.913 ms
# acc_eval:  0.9523809523809523

# %%
# 定义loss记录绘制函数
def plot_loss(hist):
    plt.plot(hist['loss'], marker='.')
    plt.plot(hist['loss_eval'], marker='.')
    plt.title('loss record')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.grid()
    plt.legend(['loss_train', 'loss_eval'], loc='upper right')
    plt.show()
    plt.close()

plot_loss(hist)

# %%
def plot_accuracy(hist):
    plt.plot(hist['acc_eval'], marker='.')
    plt.title('accuracy history')
    plt.xlabel('epoch')
    plt.ylabel('acc_eval')
    plt.grid()
    plt.show()
    plt.close()

plot_accuracy(hist)

# %%
# 使用准确率最高的参数组合建立模型，并测试其在验证集上的效果
load_checkpoint('best_param.ckpt', net=net)
res = model.eval(test_data, dataset_sink_mode=False)
print(res)
# Out:
# {'accuracy': 0.9365079365079365, 'loss': 0.17706962674856186}

# %%
# 创建图像标签列表
category_dict = {0:'Agaricus',1:'Amanita',2:'Boletus',3:'Cortinarius',4:'Entoloma',
                 5:'Hygrocybe',6:'Lactarius',7:'Russula',8:'Suillus'}

ds_test_demo = create_dataset(test_path, mean=RGB_mean, std=RGB_std, batch_size=1, usage='test')

# 将数据标准化至0~1区间
def normalize(data):
    _range = np.max(data) - np.min(data)
    return (data - np.min(data)) / _range

# 设置图像大小
plt.figure(figsize=(10,10))
i = 1
# 打印9张子图
for dic in ds_test_demo.create_dict_iterator():
    # 预测单张图片
    input_img = dic['image']
    output = model.predict(input_img)
    predict = np.argmax(output.asnumpy(),axis=1)[0] # 反馈可能性最大的类别
    
    # 可视化
    plt.subplot(3,3,i)
    input_image = np.squeeze(input_img.asnumpy(),axis=0).transpose(1,2,0) # 删除batch维度
    input_image = normalize(input_image) # 重新标准化，方便可视化
    plt.imshow(input_image)
    plt.axis('off')
    plt.title('True: %s\n Predict: %s'%(category_dict[dic['label'].asnumpy().item()],category_dict[predict]))
    i +=1
    if i > 9 :
        break

plt.show()
